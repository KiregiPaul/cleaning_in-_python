# %%
from bs4 import BeautifulSoup
import requests
import matplotlib
import time 
import datetime

# %%
url = 'https://www.ke.sportpesa.com/en/mega-jackpot-pro'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36","Accept-Encoding": "gzip, deflate", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7","Upgrade-Insecure-Requests": "1", 
}

# %%
page = requests.get(url,headers=headers)
soup1 = BeautifulSoup(page.content, "html.parser")
print(soup1)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-KE">
# <head>
# <script>
#     window.dataLayer =  window.dataLayer || [];
#     var AppAnalytics = {
#         data: {
#             breakpoint: function() {
#                 function isMobileMediaQuery() {
#                     var mobileMaxWidthMediaQuery = 767;
#                     return window.matchMedia ?
#                         window.matchMedia('(max-width: ' + mobileMaxWidthMediaQuery + 'px)').matches :
#                         Math.max(document.documentElement.clientWidth, window.innerWidth || 0) <= mobileMaxWidthMediaQuery;
#                 }
#                 var isMobileView = 0;
#                 return isMobileView || isMobileMediaQuery() ? 'mobile' : 'desktop';
#             },
#             stagingEnvironment: ~location.hostname.indexOf('ke.sportpesa.com') ? 'live' : 'staging',
#             loggedIn: 'logged out',
#             userFTB: ''
#         },
#         pushEvent: function(event) {try {
# ...

# %%
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-KE">
# <head>
# <script>
#    window.dataLayer =  window.dataLayer || [];
#     var AppAnalytics = {
#         data: {
#             breakpoint: function() {
#                 function isMobileMediaQuery() {
#                     var mobileMaxWidthMediaQuery = 767;
#                     return window.matchMedia ?
#                         window.matchMedia('(max-width: ' + mobileMaxWidthMediaQuery + 'px)').matches :
#                         Math.max(document.documentElement.clientWidth, window.innerWidth || 0) <= mobileMaxWidthMediaQuery;
#                 }
#                 var isMobileView = 0;
#                 return isMobileView || isMobileMediaQuery() ? 'mobile' : 'desktop';
#             },
#             stagingEnvironment: ~location.hostname.indexOf('ke.sportpesa.com') ? 'live' : 'staging',
#             loggedIn: 'logged out',
#             userFTB: ''
#         },
#         pushEvent: function(event) {try {
# ...

# %%
title = soup2.find(id= "event-row")
print(title)
# Out:
# None

# %%
import csv
header = ["title", "1", "x" "2"]
data = [title, 1, x, 2]
type(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 import csv
#       2 header = ["title", "1", "x" "2"]
# ----> 3 data = [title, 1, x, 2]
#       4 type(data)
#
# NameError: name 'x' is not defined

# %%
soup2.find_all("class")
# Out:
# []

# %%
soup2.find_all("list-v2-content")
# Out:
# []

# %%
soup2.find_all("<div class='list-v2-content'>")
# Out:
# []

# %%
soup2.find_all("head")
# Out:
# [<head>
#  <script>
#     window.dataLayer =  window.dataLayer || [];
#      var AppAnalytics = {
#          data: {
#              breakpoint: function() {
#                  function isMobileMediaQuery() {
#                      var mobileMaxWidthMediaQuery = 767;
#                      return window.matchMedia ?
#                          window.matchMedia('(max-width: ' + mobileMaxWidthMediaQuery + 'px)').matches :
#                          Math.max(document.documentElement.clientWidth, window.innerWidth || 0) <= mobileMaxWidthMediaQuery;
#                  }
#                  var isMobileView = 0;
#                  return isMobileView || isMobileMediaQuery() ? 'mobile' : 'desktop';
#              },
#              stagingEnvironment: ~location.hostname.indexOf('ke.sportpesa.com') ? 'live' : 'staging',
#              loggedIn: 'logged out',
#              userFTB: ''
#          },
#          pushEvent: function(event) {try {
#                  window.dataLayer.push(event);
# ...
